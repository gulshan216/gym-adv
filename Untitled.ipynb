# %%
from rllab.envs.gym_env import GymEnv
from rllab.envs.normalized_env import normalize
env = normalize(GymEnv("HalfCheetahAdv-v1", 1.0))
# Out:
# 2018-11-04 21:30:07.627304 CST | Warning: skipping Gym environment monitoring since snapshot_dir not configured.
# [2018-11-04 21:30:07,628] Making new env: HalfCheetahAdv-v1
# running build_ext
# building 'mujoco_py.cymj' extension
# C compiler: gcc -pthread -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -fPIC
#
# compile options: '-I/home/gulshan/.local/lib/python3.5/site-packages/mujoco_py -I/home/gulshan/.mujoco/mjpro150/include -I/home/gulshan/.local/lib/python3.5/site-packages/numpy/core/include -I/home/gulshan/.local/lib/python3.5/site-packages/mujoco_py/vendor/egl -I/home/gulshan/miniconda3/envs/rllab3-adv/include/python3.5m -c'
# extra options: '-fopenmp -w'
# gcc: /home/gulshan/.local/lib/python3.5/site-packages/mujoco_py/cymj.c
# gcc: /home/gulshan/.local/lib/python3.5/site-packages/mujoco_py/gl/eglshim.c
# /home/gulshan/.local/lib/python3.5/site-packages/mujoco_py/gl/eglshim.c:9:20: fatal error: mujoco.h: No such file or directory
#  #include "mujoco.h"
# ...
